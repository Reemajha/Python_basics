# %%
import json
import pandas as pd

# %%
f = open("reema.json",'r')
data = f.read()
print(data)
# Out:
# {
#     "Functions": [
#         {
#             "FunctionName": "sqslambda",
#             "FunctionArn": "arn:aws:lambda:us-east-1:620146510266:function:sqslambda",
#             "Runtime": "nodejs12.x",
#             "Role": "arn:aws:iam::620146510266:role/sqslambdarole",
#             "Handler": "index.handler",
#             "CodeSize": 312,
#             "Description": "lambda invoked by sqs and check conditions and call another lambda based on condition",
#             "Timeout": 3,
#             "MemorySize": 128,
#             "LastModified": "2021-07-02T18:55:18.790+0000",
#             "CodeSha256": "KxGnNFE9FAj3G48lC7GlYTlyGLWZlW5kO+O4oRYymow=",
#             "Version": "$LATEST",
#             "TracingConfig": {
#                 "Mode": "PassThrough"
#             },
#             "RevisionId": "95b70577-72cd-4c23-865a-a67edb776875",
#             "PackageType": "Zip"
#         },
#         {
#             "FunctionName": "iamuserdata",
# ...

# %%
f_data = json.loads(data)

# %%
type(f_data)
# Out:
# dict

# %%
parse = f_data["Functions"]

# %%
#parse

# %%
ls = []

# %%
for i in parse:
    
    ls.append(i["FunctionName"])

print(ls)
# Out:
# ['sqslambda', 'iamuserdata', 'cloudwatchtoelasticsearch', 'securityhubcheck', 'prsendnotification', 'userdatacommit', 'testcustomruntime', 'testiam', 'testnewlambda', 'Mehultesting', 'test-sqs', 'trialdemo', 'testvscode', 'apigatewattest', 'test', 'sqslambda', 'iamuserdata', 'cloudwatchtoelasticsearch', 'securityhubcheck', 'prsendnotification', 'userdatacommit', 'testcustomruntime', 'testiam', 'testnewlambda', 'Mehultesting', 'test-sqs', 'trialdemo', 'testvscode', 'apigatewattest', 'test', 'sqslambda', 'iamuserdata', 'cloudwatchtoelasticsearch', 'securityhubcheck', 'prsendnotification', 'userdatacommit', 'testcustomruntime', 'testiam', 'testnewlambda', 'Mehultesting', 'test-sqs', 'trialdemo', 'testvscode', 'apigatewattest', 'test']

# %%
df = pd.DataFrame({"FunctionName":ls})

# %%
df.head()
# Out:
#                 FunctionName
# 0                  sqslambda
# 1                iamuserdata
# 2  cloudwatchtoelasticsearch
# 3           securityhubcheck
# 4         prsendnotification

# %%
df.to_csv('reema_file2.csv')
